# %%
total_cards <- 52
kings <- 4

#a

P_E1E2 <- (kings/total_cards) * ((kings - 1)/(total_cards - 1))
P_E1E2

#b

P_no_king <- ((48/52) * (47/51))
P_E1_or_E2 <- 1 - P_no_king
P_E1_or_E2

#c


P_no_king_first_two <- (48/52) * (47/51)
P_E1_or_E2 <- 1 - P_no_king_first_two
P_E1_or_E2

#d

P_E3_given_E1E2 <- (kings - 2)/(total_cards - 2)
P_E3_given_E1E2

#e

P_E1E2E3 <- (kings/total_cards) *
            ((kings - 1)/(total_cards - 1)) *
            ((kings - 2)/(total_cards - 2))

P_E1E2E3

#f


P_E1E2 <- (4/52) * (3/51)
P_E2E3 <- (4/52) * (3/51)
P_E1E2E3 <- (4/52) * (3/51) * (2/50)

P_union <- P_E1E2 + P_E2E3 - P_E1E2E3
P_union


#prob 2
#a

dice <- expand.grid(d1 = 1:6, d2 = 1:6, d3 = 1:6)

dice$X <- dice$d1 + dice$d2 + dice$d3

dist_X <- table(dice$X) / nrow(dice)
dist_X

#b

sum(dist_X[names(dist_X) %in% 7:11])



#prob 3
#a

x <- c(-10, -20, 30)
p <- c(1/5, 3/10, 1/2)

EX <- sum(x * p)
EX

#b

EX2 <- sum(x^2 * p)
EX2

#c

VarX <- sum((x - EX)^2 * p)
VarX

#d

EX3 <- sum(x^3 * p)
EX3


#prob 4
#a

factorial(5)

#b

factorial(5) - factorial(4)


#c


factorial(2) * factorial(3)



#prob 5
#a


choose(6,2) * choose(8,4) * choose(4,3) * choose(5,3)

#b


choose(5,1) * choose(7,3) * choose(4,3) * choose(5,3)

#prob 6


P_E1 <- 4/52
P_E2 <- 4/52
P_E1E2 <- (4/52)*(3/51)

P_union <- P_E1 + P_E2 - P_E1E2

P_union <= (P_E1 + P_E2)

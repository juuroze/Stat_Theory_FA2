# %%
# 9.21

data <- c(8.3, 10.6, 9.7, 8.8, 10.2, 9.4)

# sample mean
mean(data)

# unbiased variance
var(data)

# sample standard deviation
sd(data)

# MLE variance
var_mle <- sum((data - mean(data))^2)/length(data)
var_mle

# MLE standard deviation
sqrt(var_mle )

cat("\n")


# 9.24

xbar <- 11.09
s <- 0.73
n <- 60

SE <- s/sqrt(n)

# 95% CI
lower95 <- xbar - 1.96*SE
upper95 <- xbar + 1.96*SE

# 99% CI
lower99 <- xbar - 2.576*SE
upper99 <- xbar + 2.576*SE

lower95; upper95
lower99; upper99

cat("\n")

# 9.33

n1 <- 50
n2 <- 100
x1 <- 7.82
x2 <- 6.75
s1 <- 0.24
s2 <- 0.30

diff <- x1 - x2
SE <- sqrt((s1^2/n1) + (s2^2/n2))

# 95% CI
lower95 <- diff - 1.96*SE
upper95 <- diff + 1.96*SE

# 99% CI
lower99 <- diff - 2.576*SE
upper99 <- diff + 2.576*SE

lower95; upper95
lower99; upper99

cat("\n")


males <- c(
85,53,100,49,65,
60,51,61,83,65,
55,99,56,55,55,
90,72,62,69,59,
49,72,58,60,68,
90,74,85,80,77,
62,65,81,55,71,
78,49,78,80,75,
53,82,109,87,78,
72,104,70,31,50)

females <- c(
64,93,82,71,77,
64,60,75,87,60,
61,84,91,61,85,
105,90,59,86,62,
71,99,98,54,94,
98,61,108,79,50,
66,74,60,90,95,
81,86,65,86,81,
92,77,82,86,79,
91,93,63,93,53)

mean(males)
mean(females)
sd(males)
sd(females)
# Out:
# [1] 9.5
# [1] 0.736
# [1] 0.8579044
# [1] 0.6133333
# [1] 0.783156
# [1] 10.90528
# [1] 11.27472
# [1] 10.84723
# [1] 11.33277
# [1] 0.9812139
# [1] 1.158786
# [1] 0.9533098
# [1] 1.18669
# [1] 69.74
# [1] 78.44
# [1] 16.23527
# [1] 14.89577
